# %% [markdown]
# <a href="https://colab.research.google.com/github/YatalaSneha24/PythonAssessmentPractice/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing Keywords and Printing them
import keyword
keywords = keyword.kwlist
print("List of the Kewords:")
print("-----------------------")
print(keywords)
# Out:
# List of the Kewords:
# -----------------------
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Single Line print
print("My name is Yatala Sneha", "I am", 24, "years old." )

#Concatenating Strings
surname="Yatala"
lastname="Sneha"
print("Hi,", surname + " " + lastname , "!")

#Multiline printing using triple quotes
print("""Hello, Yatala Sneha.
How are your?
I want to talk with you.""")

#Multiline printin using escape characters
print("Do you know about this tree? \nIt is the biggest tree in the world \nYou can see its flowers.")
# Out:
# My name is Yatala Sneha I am 24 years old.
# Hi, Yatala Sneha !
# Hello, Yatala Sneha.
# How are your?
# I want to talk with you.
# Do you know about this tree?
# It is the biggest tree in the world
# You can see its flowers.
