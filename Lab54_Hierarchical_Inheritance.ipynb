# %% [markdown]
# <a href="https://colab.research.google.com/github/YatalaSneha24/PythonAssessmentPractice/blob/main/Lab54_Hierarchical_Inheritance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Python Program Demonstrating Hierarchical Inheritance

#Task 1: Define the Base Class Person
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def display_personal_details(self):
        return f"Name: {self.name}, Age: {self.age}"
class Employee(Person):
    def __init__(self, name, age, employee_id, salary):
            super().__init__(name, age)
            self.employee_id = employee_id
            self.salary = salary
    def display_employee_details(self):
        personal_details = self.display_personal_details()
        return f"{personal_details}, Employee ID: {self.employee_id}, Salary: ${self.salary:.2f}"
class Manager(Person):
    def __init__(self, name, age, department, team_size):
        super().__init__(name, age)
        self.department = department
        self.team_size =  team_size

    def display_manager_details(self):
        personal_details = self.display_personal_details()
        return f"{personal_details}, Department: {self.department}, Team Size: {self.team_size}"

if __name__ == "__main__":
    employee = Employee("Sneha", 22, "E12345", 50000)
    manager = Manager("Rabin", 20, "Sales", 12)

    print("Employee details:")
    print(employee.display_personal_details())
    print("\nManager Details:")
    print(manager.display_manager_details())
# Out:
# Employee details:
# Name: Sneha, Age: 22
#
# Manager Details:
# Name: Rabin, Age: 20, Department: Sales, Team Size: 12
