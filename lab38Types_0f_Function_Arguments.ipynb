# %% [markdown]
# <a href="https://colab.research.google.com/github/YatalaSneha24/PythonAssessmentPractice/blob/main/lab38Types_0f_Function_Arguments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Implementation of Python Function Arguments with different types

#Task 1:  Implementation of  Positional Arguments
def greeting(name,age):
    print(f"Hello {name}, you are {age} years old.")
greeting("Sneha", 22)
# Out:
# Hello Sneha, you are 22 years old.

# %%
#Task 2:  Implementation of  Keyword Arguments

def greeting(name, age):
    print(f"Hello {name}, you are {age} years old.")
greeting(age=22, name="Sneha")  #keyword arguments
# Out:
# Hello Sneha, you are 22 years old.

# %%
#Task 3:  Implementation of  Default Arguments
def greeting(name, age=22):
    print(f"Hello {name}, you are {age} years old.")
greeting("Sneha")
greeting("Pranavi", 21)
# Out:
# Hello Sneha, you are 22 years old.
# Hello Pranavi, you are 21 years old.

# %%
#Task 4:  Implementation of  Variable-Length Arguments
def print_numbers(*agrs):
    for num in agrs:
        print(num)
print_numbers(0, 1, 2, 3, 4, 5) #variable-length positional arguments
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#Task 5:  Implementation of  Keyword Variable-Length Arguments (**kwargs)
def print_info(**kwargs):
    for key, value in kwargs.items():
      print(f"{key}: {value}")

print_info(name="Sneha", profession="Engineer")
print_info(country="India", population=1.49, capital="New Delhi")
print_info(a="1", b="2", c="3")
# Out:
# name: Sneha
# profession: Engineer
# country: India
# population: 1.49
# capital: New Delhi
# a: 1
# b: 2
# c: 3

# %%
#Task 6:  Implementation of  Mixing Different Argument Types
def mixed_arguments(a, b=4, *args, **kwargs):
    print(f"a: {a}")
    print(f"b: {b}")
    print(f"args:", args)
    print(f"kwargs:", kwargs)

mixed_arguments(1,2,3,4,5, y=10, s=30)
# Out:
# a: 1
# b: 2
# args: (3, 4, 5)
# kwargs: {'y': 10, 's': 30}
